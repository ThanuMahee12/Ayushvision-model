# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %run ../../Util/FileFolder
# %run ../../Util/Variable
# %run ../../Util/ImageProcessing
# Out:
# created

# %%
create_new_folders(today_analysis_path)

# %%
ImageDatasetFrame=pd.read_csv(os.path.join(today_collection_summary_path,'imageDatasetVeiwcsv.csv'))

# %%
plt.figure(figsize=(12, 10))  # Set the figure size (width, height) in inches
colors = [plt.cm.tab20c(i/len(ImageDatasetFrame['Path'])) for i in range(len(ImageDatasetFrame['Path']))]
# Plot bars
plt.bar(ImageDatasetFrame['Path'], ImageDatasetFrame['VolumeMB'], color=colors)

# Customize chart
plt.xlabel('Files')  # X-axis label
plt.ylabel('Volume')  # Y-axis label
plt.title('Volume Vs Imageset')  # Chart title
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility if needed

# Show plot
plt.tight_layout()  # Adjust layout for better appearance of labels
plt.show()
plt.savefig(os.path.join(today_analysis_path,'imageCapacitygraph.png'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 4
#       2 colors = [plt.cm.tab20c(i/len(ImageDatasetFrame['Path'])) for i in range(len(ImageDatasetFrame['Path']))]
#       3 # Plot bars
# ----> 4 plt.bar(ImageDatasetFrame['Path'], ImageDatasetFrame['VolumeMB'], color=colors)
#       6 # Customize chart
#       7 plt.xlabel('Files')  # X-axis label
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
# ...

# %%
subfolderPaths=subfolders_path(original_dataset_dir)

# %%
for subfolder in subfolderPaths:
    corropeted_images=find_corrupted_images(subfolder)
    if len(corropeted_images)>=0:
        with open(today_analysis_path,'faltfiles',f'{os.path.join(os.path.basename(subfolder))}', 'a') as file:
            file.writelines(corropeted_images)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 corropeted_images=find_corrupted_images(original_dataset_dir)
#
# File ~\Documents\AyushVision\ayush-vision\Util\ImageProcessing.py:215, in find_corrupted_images(directory)
#     213         if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
#     214             image_path = os.path.join(root, file)
# --> 215             if is_corrupted_pillow(image_path) or is_corrupted_opencv(image_path):
#     216                 corrupted_images.append(image_path)
#     217 return corrupted_images
#
# File ~\Documents\AyushVision\ayush-vision\Util\ImageProcessing.py:202, in is_corrupted_opencv(image_path)
#     200 def is_corrupted_opencv(image_path):
#     201     try:
# --> 202         img = cv2.imread(image_path)
#     203         if img is None:
#     204             return True
#
# ...

# %%
corropeted_images

# %%
subfolderCounCsvDf=pd.read_csv(os.path.join(today_collection_summary_path,'reportcsv.csv'))

# %%
plt.figure(figsize=(20, 15))  # Set the figure size (width, height) in inches
colors = [plt.cm.tab20c(i/len(subfolderCounCsvDf['Names'])) for i in range(len(subfolderCounCsvDf['Names']))]
# Plot bars
plt.bar(subfolderCounCsvDf['Names'], subfolderCounCsvDf['Files'], color=colors)

# Customize chart
plt.xlabel('Species')  # X-axis label
plt.ylabel('Count')  # Y-axis label
plt.title('Count Vs Species')  # Chart title
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility if needed

# Show plot
plt.tight_layout()  # Adjust layout for better appearance of labels
plt.savefig(os.path.join(today_analysis_path,'SpeciesCount.png'))
plt.show()

# %%
plt.figure(figsize=(12, 10))  # Set the figure size (width, height) in inches
colors = [plt.cm.tab20c(i/len(subfolderCounCsvDf['Names'])) for i in range(len(subfolderCounCsvDf['Names']))]
# Plot bars
plt.bar(subfolderCounCsvDf['Names'], subfolderCounCsvDf['Volume MB'], color=colors)

# Customize chart
plt.xlabel('Species')  # X-axis label
plt.ylabel('Volume MB')  # Y-axis label
plt.title('Volume MB Vs Species')  # Chart title
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility if needed

# Show plot
plt.tight_layout()  # Adjust layout for better appearance of labels
plt.savefig(os.path.join(today_analysis_path,'SpeciesVolume.png'))
plt.show()
