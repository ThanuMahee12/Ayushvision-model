# %%
import os

# %%
import pandas as pd

# %%
# %run ../../Util/FileFolder
# Out:
# created

# %%
# %run ../../Util/Variable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\Research\ayush-vision\Util\Variable.py:17
#      15 working_dirctory=os.getenv("TARGET_DATASET_PATH")
#      16 working_dir_name=os.getenv('WORKING_DIR_NAME')
# ---> 17 ayush_classFication_Working=os.path.join(working_dirctory,working_dir_name,'classification')
#      18 ayush_detection_Working=os.path.join(working_dirctory,working_dir_name,'detection')
#
# File <frozen ntpath>:147, in join(path, *paths)
#
# File <frozen genericpath>:152, in _check_arg_types(funcname, *args)
#
# TypeError: join() argument must be str, bytes, or os.PathLike object, not 'NoneType'

# %%
eligible_count=1500

# %%
today_collection_path=os.path.join(today_summary_path,'collection') # from Variables

# %%
today_analysis_path=os.path.join(today_summary_path,'analysis','classfication') # from Variables

# %%
create_new_folders(today_analysis_path)
# Out:
# 'already exsist'

# %%
subfolderCsv=os.path.join(today_collection_path,'reportcsv.csv')

# %%
sub_folders_df=pd.read_csv(subfolderCsv)

# %%
sub_folders_df['Eligible']=sub_folders_df[['Files']].max(axis=1) >= eligible_count

# %%
sub_folders_df
# Out:
#                    Names                                   Path  Files  \
# 0        Adamant Creeper       E:\\D disk\Ayush\Adamant Creeper   1501
# 1                Alovera               E:\\D disk\Ayush\Alovera   1513
# 2                  Betel                 E:\\D disk\Ayush\Betel   1500
# 3      Black-Honey Shrub     E:\\D disk\Ayush\Black-Honey Shrub   1517
# 4                 Caster                E:\\D disk\Ayush\Caster   1500
# 5           Cat whiskers          E:\\D disk\Ayush\Cat whiskers   1110
# 6               Cinnamon              E:\\D disk\Ayush\Cinnamon   1500
# 7                 erukku                E:\\D disk\Ayush\erukku    301
# 8                 ginger                E:\\D disk\Ayush\ginger   1501
# 9                  Henna                 E:\\D disk\Ayush\Henna   1500
# 10              Hibiscus              E:\\D disk\Ayush\Hibiscus   1495
# 11            Holy Basil            E:\\D disk\Ayush\Holy Basil   1314
# ...

# %%
sub_folders_df.to_csv(os.path.join(today_analysis_path,'species_eligibli_overveiw.csv'))
sub_folders_df.to_excel(os.path.join(today_analysis_path,'species_eligibli_overveiw.xlsx'))

# %%
sub_folders_df.to_json(os.path.join(today_analysis_path,'species_eligibli_overveiw.json'))

# %%
sub_folders_df.drop(columns=[ 'Volume MB','subfolders'], inplace=True)

# %%
sub_folders_df
# Out:
#                    Names                                   Path  Files  \
# 0        Adamant Creeper       E:\\D disk\Ayush\Adamant Creeper   1501
# 1                Alovera               E:\\D disk\Ayush\Alovera   1513
# 2                  Betel                 E:\\D disk\Ayush\Betel   1500
# 3      Black-Honey Shrub     E:\\D disk\Ayush\Black-Honey Shrub   1517
# 4                 Caster                E:\\D disk\Ayush\Caster   1500
# 5           Cat whiskers          E:\\D disk\Ayush\Cat whiskers   1110
# 6               Cinnamon              E:\\D disk\Ayush\Cinnamon   1500
# 7                 erukku                E:\\D disk\Ayush\erukku    301
# 8                 ginger                E:\\D disk\Ayush\ginger   1501
# 9                  Henna                 E:\\D disk\Ayush\Henna   1500
# 10              Hibiscus              E:\\D disk\Ayush\Hibiscus   1495
# 11            Holy Basil            E:\\D disk\Ayush\Holy Basil   1314
# ...

# %%
sub_folders_df.to_csv(os.path.join(today_analysis_path,'classfication_species_eligible.csv'))

# %%
eligible_specises=sub_folders_df.loc[sub_folders_df['Files'] >= eligible_count]

# %%
eligible_specises['extra']=sub_folders_df['Files']-1500
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10432\1719218869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eligible_specises['extra']=sub_folders_df['Files']-1500

# %%
eligible_specises
# Out:
#                    Names                                   Path  Files  \
# 0        Adamant Creeper       E:\\D disk\Ayush\Adamant Creeper   1501
# 1                Alovera               E:\\D disk\Ayush\Alovera   1513
# 2                  Betel                 E:\\D disk\Ayush\Betel   1500
# 3      Black-Honey Shrub     E:\\D disk\Ayush\Black-Honey Shrub   1517
# 4                 Caster                E:\\D disk\Ayush\Caster   1500
# 6               Cinnamon              E:\\D disk\Ayush\Cinnamon   1500
# 8                 ginger                E:\\D disk\Ayush\ginger   1501
# 9                  Henna                 E:\\D disk\Ayush\Henna   1500
# 12       Indian acalypha       E:\\D disk\Ayush\Indian acalypha   1500
# 13         indian Mallow         E:\\D disk\Ayush\indian Mallow   1500
# 14             ivy gourd             E:\\D disk\Ayush\ivy gourd   1500
# 15              Landrina              E:\\D disk\Ayush\Landrina   1500
# ...

# %%
eligible_specises.to_csv(os.path.join(today_analysis_path,'classification_eligible.csv'))

# %%
non_eligible_specises=sub_folders_df.loc[sub_folders_df['Files'] < eligible_count]

# %%
non_eligible_specises['pending']=1500-sub_folders_df['Files']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10432\813507014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_eligible_specises['pending']=1500-sub_folders_df['Files']

# %%
non_eligible_specises
# Out:
#            Names                           Path  Files  Eligible  pending
# 5   Cat whiskers  E:\\D disk\Ayush\Cat whiskers   1110     False      390
# 7         erukku        E:\\D disk\Ayush\erukku    301     False     1199
# 10      Hibiscus      E:\\D disk\Ayush\Hibiscus   1495     False        5
# 11    Holy Basil    E:\\D disk\Ayush\Holy Basil   1314     False      186
# 16   Lemon grass   E:\\D disk\Ayush\Lemon grass   1431     False       69
# 17          lime          E:\\D disk\Ayush\lime   1392     False      108
# 21          Neem          E:\\D disk\Ayush\Neem   1423     False       77
# 27  Sleepy Plant  E:\\D disk\Ayush\Sleepy Plant   1319     False      181

# %%
non_eligible_specises.to_csv(os.path.join(today_analysis_path,'classification_non_elible.csv'))
