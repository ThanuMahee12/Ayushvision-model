# %%
import pandas as pd

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %run ../../Util/Variable

# %%
# %run ../../Util/FileFolder
# Out:
# created

# %%
today_collection_path=os.path.join(today_summary_path,'collection') # from Variables

# %%
reportjsonfile=os.path.join(today_collection_path,'reportjsonfile.json')

# %%
jsonFilRead=pd.read_json(reportjsonfile)

# %%
Subfolders=pd.DataFrame(jsonFilRead['subfolder'].values.tolist())

# %%
Subfolders
# Out:
#                     name                                   path  filecount  \
# 0        Adamant Creeper       E:\\D disk\Ayush\Adamant Creeper       1506
# 1                Alovera               E:\\D disk\Ayush\Alovera       1513
# 2                  Betel                 E:\\D disk\Ayush\Betel       1500
# 3      Black-Honey Shrub     E:\\D disk\Ayush\Black-Honey Shrub       1517
# 4                 Caster                E:\\D disk\Ayush\Caster       1500
# 5           Cat whiskers          E:\\D disk\Ayush\Cat whiskers       1110
# 6               Cinnamon              E:\\D disk\Ayush\Cinnamon       1500
# 7                 erukku                E:\\D disk\Ayush\erukku       1151
# 8                 ginger                E:\\D disk\Ayush\ginger       1501
# 9                  Henna                 E:\\D disk\Ayush\Henna       1500
# 10              Hibiscus              E:\\D disk\Ayush\Hibiscus       1562
# 11            Holy Basil            E:\\D disk\Ayush\Holy Basil       1670
# 12       Indian acalypha       E:\\D disk\Ayush\Indian acalypha       1500
# 13         indian Mallow         E:\\D disk\Ayush\indian Mallow       1500
# 14             ivy gourd             E:\\D disk\Ayush\ivy gourd       1500
# 15              Landrina              E:\\D disk\Ayush\Landrina       1500
# 16           Lemon grass           E:\\D disk\Ayush\Lemon grass       1530
# 17                  lime                  E:\\D disk\Ayush\lime       1552
# 18           long Pepper           E:\\D disk\Ayush\long Pepper       1509
# 19          Miracle Leaf          E:\\D disk\Ayush\Miracle Leaf       1500
# 20    Mountain Knotgrass    E:\\D disk\Ayush\Mountain Knotgrass       1519
# 21                  Neem                  E:\\D disk\Ayush\Neem       1586
# 22               Oregano               E:\\D disk\Ayush\Oregano       1501
# 23        Pedalium murex        E:\\D disk\Ayush\Pedalium murex       1500
# 24      Red Pea Eggplant      E:\\D disk\Ayush\Red Pea Eggplant       1535
# 25        Ringworm Plant        E:\\D disk\Ayush\Ringworm Plant       1601
# 26    Seeds under leaves    E:\\D disk\Ayush\Seeds under leaves       1501
# 27          Sleepy Plant          E:\\D disk\Ayush\Sleepy Plant       1319
# 28  tall perennial grass  E:\\D disk\Ayush\tall perennial grass       1539
# 29           Thorn Apple           E:\\D disk\Ayush\Thorn Apple       1500
# 30              turmeric              E:\\D disk\Ayush\turmeric       1501
# 31         Vitex negundo         E:\\D disk\Ayush\Vitex negundo       1511
# 32         Wild Turmaric         E:\\D disk\Ayush\Wild Turmaric       1991
#
#                                                volume  \
# 0   {'GB': 4.914096983149648, 'KB': 5152804.158203...
# 1   {'GB': 4.886933599598706, 'KB': 5124321.286132...
# 2   {'GB': 4.355446450412273, 'KB': 4567016.617187...
# 3   {'GB': 4.476687587797642, 'KB': 4694147.164062...
# 4   {'GB': 5.194900737144053, 'KB': 5447248.235351...
# 5   {'GB': 4.146954176947474, 'KB': 4348396.623046...
# 6   {'GB': 4.4096250385046, 'KB': 4623826.984375, ...
# 7   {'GB': 4.754620676860213, 'KB': 4985581.130859...
# 8   {'GB': 4.4999858140945435, 'KB': 4718577.125, ...
# 9   {'GB': 4.256869252771139, 'KB': 4463650.933593...
# 10  {'GB': 4.623481987975538, 'KB': 4848072.249023...
# 11  {'GB': 5.197707256302237, 'KB': 5450191.083984...
# 12  {'GB': 3.7994639864191413, 'KB': 3984026.74902...
# 13  {'GB': 5.19551242236048, 'KB': 5447889.6337890...
# 14  {'GB': 3.900189436040818, 'KB': 4089645.038085...
# 15  {'GB': 4.213077673688531, 'KB': 4417732.134765...
# 16  {'GB': 5.036520248278975, 'KB': 5281174.255859...
# 17  {'GB': 4.716870594769716, 'KB': 4945997.300781...
# 18  {'GB': 4.488442732952535, 'KB': 4706473.327148...
# 19  {'GB': 4.853316185995936, 'KB': 5089070.873046...
# 20  {'GB': 4.119182935915887, 'KB': 4319276.366210...
# 21  {'GB': 5.972177676856518, 'KB': 6262282.179687...
# 22  {'GB': 4.27921655215323, 'KB': 4487083.7753906...
# 23  {'GB': 4.242626687511802, 'KB': 4448716.521484...
# 24  {'GB': 4.371802374720573, 'KB': 4584167.046875...
# 25  {'GB': 5.943642467260361, 'KB': 6232360.84375,...
# 26  {'GB': 4.706921575590968, 'KB': 4935564.998046...
# 27  {'GB': 4.953554086387157, 'KB': 5194177.929687...
# 28  {'GB': 5.352946015074849, 'KB': 5612970.720703...
# 29  {'GB': 5.642520963214338, 'KB': 5916612.061523...
# 30  {'GB': 6.306307692080736, 'KB': 6612642.894531...
# 31  {'GB': 4.596429508179426, 'KB': 4819705.667968...
# 32  {'GB': 6.238383384421468, 'KB': 6541419.095703...
#
#                                            subfolders
# 0   [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 1   [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Al...
# 2   [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Be...
# 3   [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Bl...
# 4   [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Ca...
# 5   [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 6   [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Ci...
# 7   [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 8   [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\gi...
# 9   [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\He...
# 10  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 11  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 12  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 13  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 14  [{'name': 'fruits', 'path': 'E:\\D disk\Ayush\...
# 15  [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\La...
# 16  [{'name': 'leaves', 'path': 'E:\\D disk\Ayush\...
# 17  [{'name': 'fruit', 'path': 'E:\\D disk\Ayush\l...
# 18  [{'name': 'kaai', 'path': 'E:\\D disk\Ayush\lo...
# 19  [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Mi...
# 20  [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Mo...
# 21  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 22  [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Or...
# 23  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 24  [{'name': 'Flower', 'path': 'E:\\D disk\Ayush\...
# 25  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 26  [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\Se...
# 27  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 28  [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\ta...
# 29  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 30  [{'name': 'leaf', 'path': 'E:\\D disk\Ayush\tu...
# 31  [{'name': 'flower', 'path': 'E:\\D disk\Ayush\...
# 32  [{'name': 'kilanku', 'path': 'E:\\D disk\Ayush...

# %%
# Plotting a bar chart
plt.figure(figsize=(10, 8))  # Set the figure size (width, height) in inches
colors = [plt.cm.tab20c(i/len(Subfolders['name'])) for i in range(len(Subfolders['name']))]
# Plot bars
plt.bar(Subfolders['name'], Subfolders['filecount'], color=colors)

# Customize chart
plt.xlabel('Specices')  # X-axis label
plt.ylabel('Count')  # Y-axis label
plt.title('Specises Vs Count')  # Chart title
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility if needed

# Show plot
plt.tight_layout()  # Adjust layout for better appearance of labels
plt.show()

# %%
sub_folders=jsonFilRead['subfolder'].values.tolist()

# %%
subfolder_details=[]
for sub in sub_folders:
    subsub_dict={'name':sub['name']}
    for s in sub['subfolders']:
        if s['name'] =='plants' or s['name']=='Plant' or s['name']=='plant' or s['name']=='Plants' or s['name']=='p':
            subsub_dict['plants']=s['filecount']
        elif s['name']=='leaf' or s['name']=='leaves' or s['name']=='Leaf':
            subsub_dict['leaves']=s['filecount']
        elif s['name']=='fruit' or s['name']=='fruits' or  s['name']=='kaai' or s['name']=='kai':
            subsub_dict['raw_fruits']=s['filecount']
        elif s['name']=='flower' or s['name']=='Flower':
            subsub_dict['flowers']=s['filecount']
        elif s['name']=='Root' or s['name']=='root':
            subsub_dict['roots']=s['filecount']
        elif s['name']=='kilanku':
            subsub_dict['tumber']=s['filecount']
        else :
            subsub_dict['name']=s['filecount']
    subfolder_details.append(subsub_dict)

# %% [markdown]
# #### Subparts Details

# %%
subfolder_details_df=pd.DataFrame(subfolder_details)

# %%
subfolder_details_df
# Out:
#                     name  flowers  leaves  plants  roots  raw_fruits  tumber
# 0        Adamant Creeper    182.0   730.0     594    NaN         NaN     NaN
# 1                Alovera      NaN   513.0    1000    NaN         NaN     NaN
# 2                  Betel      NaN   750.0     750    NaN         NaN     NaN
# 3      Black-Honey Shrub      NaN   620.0     897    NaN         NaN     NaN
# 4                    385      NaN   500.0     615    NaN         NaN     NaN
# 5           Cat whiskers    427.0   296.0     387    NaN         NaN     NaN
# 6               Cinnamon      NaN   877.0     623    NaN         NaN     NaN
# 7                 erukku    237.0   532.0     382    NaN         NaN     NaN
# 8                 ginger      NaN   535.0     766  200.0         NaN     NaN
# 9                  Henna      NaN   750.0     750    NaN         NaN     NaN
# 10              Hibiscus    300.0   650.0     612    NaN         NaN     NaN
# 11            Holy Basil    414.0   575.0     681    NaN         NaN     NaN
# 12       Indian acalypha    300.0   550.0     650    NaN         NaN     NaN
# 13         indian Mallow    400.0   500.0     600    NaN         NaN     NaN
# 14             ivy gourd      NaN   550.0     732    NaN       218.0     NaN
# 15              Landrina      NaN   750.0     750    NaN         NaN     NaN
# 16           Lemon grass      NaN   780.0     750    NaN         NaN     NaN
# 17                  lime      NaN   631.0     687    NaN       234.0     NaN
# 18           long Pepper      NaN   618.0     660    NaN       231.0     NaN
# 19          Miracle Leaf      NaN   760.0     740    NaN         NaN     NaN
# 20    Mountain Knotgrass      NaN   529.0     990    NaN         NaN     NaN
# 21                  Neem    171.0   746.0     669    NaN         NaN     NaN
# 22               Oregano      NaN   750.0     751    NaN         NaN     NaN
# 23                   200    200.0   500.0     600    NaN         NaN     NaN
# 24      Red Pea Eggplant    206.0   538.0     655    NaN       136.0     NaN
# 25        Ringworm Plant    300.0   500.0     601    NaN       200.0     NaN
# 26    Seeds under leaves      NaN   760.0     741    NaN         NaN     NaN
# 27          Sleepy Plant    207.0     NaN    1112    NaN         NaN     NaN
# 28  tall perennial grass      NaN   601.0     712  226.0         NaN     NaN
# 29                   132    215.0   516.0     637    NaN         NaN     NaN
# 30              turmeric      NaN   499.0     802  200.0         NaN     NaN
# 31         Vitex negundo    200.0   648.0     663    NaN         NaN     NaN
# 32         Wild Turmaric      NaN   595.0    1114    NaN         NaN   282.0

# %%
subfolder_details_df=subfolder_details_df.fillna(0)

# %%
subfolder_details_df
# Out:
#                     name  flowers  leaves  plants  roots  raw_fruits  tumber
# 0        Adamant Creeper    182.0   730.0     594    0.0         0.0     0.0
# 1                Alovera      0.0   513.0    1000    0.0         0.0     0.0
# 2                  Betel      0.0   750.0     750    0.0         0.0     0.0
# 3      Black-Honey Shrub      0.0   620.0     897    0.0         0.0     0.0
# 4                    385      0.0   500.0     615    0.0         0.0     0.0
# 5           Cat whiskers    427.0   296.0     387    0.0         0.0     0.0
# 6               Cinnamon      0.0   877.0     623    0.0         0.0     0.0
# 7                 erukku    237.0   532.0     382    0.0         0.0     0.0
# 8                 ginger      0.0   535.0     766  200.0         0.0     0.0
# 9                  Henna      0.0   750.0     750    0.0         0.0     0.0
# 10              Hibiscus    300.0   650.0     612    0.0         0.0     0.0
# 11            Holy Basil    414.0   575.0     681    0.0         0.0     0.0
# 12       Indian acalypha    300.0   550.0     650    0.0         0.0     0.0
# 13         indian Mallow    400.0   500.0     600    0.0         0.0     0.0
# 14             ivy gourd      0.0   550.0     732    0.0       218.0     0.0
# 15              Landrina      0.0   750.0     750    0.0         0.0     0.0
# 16           Lemon grass      0.0   780.0     750    0.0         0.0     0.0
# 17                  lime      0.0   631.0     687    0.0       234.0     0.0
# 18           long Pepper      0.0   618.0     660    0.0       231.0     0.0
# 19          Miracle Leaf      0.0   760.0     740    0.0         0.0     0.0
# 20    Mountain Knotgrass      0.0   529.0     990    0.0         0.0     0.0
# 21                  Neem    171.0   746.0     669    0.0         0.0     0.0
# 22               Oregano      0.0   750.0     751    0.0         0.0     0.0
# 23                   200    200.0   500.0     600    0.0         0.0     0.0
# 24      Red Pea Eggplant    206.0   538.0     655    0.0       136.0     0.0
# 25        Ringworm Plant    300.0   500.0     601    0.0       200.0     0.0
# 26    Seeds under leaves      0.0   760.0     741    0.0         0.0     0.0
# 27          Sleepy Plant    207.0     0.0    1112    0.0         0.0     0.0
# 28  tall perennial grass      0.0   601.0     712  226.0         0.0     0.0
# 29                   132    215.0   516.0     637    0.0         0.0     0.0
# 30              turmeric      0.0   499.0     802  200.0         0.0     0.0
# 31         Vitex negundo    200.0   648.0     663    0.0         0.0     0.0
# 32         Wild Turmaric      0.0   595.0    1114    0.0         0.0   282.0

# %%
subpart_csv=os.path.join(today_collection_path,'subpart_details.csv')

# %%
subfolder_details_df.to_csv(subpart_csv)

# %%
# Set the figure size
fig, ax = plt.subplots(figsize=(14, 8))

# Number of bars
N = len(subfolder_details_df)

# Index for the x-axis
ind = np.arange(N)

# Width of a bar
width = 0.3
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
# Plot each count type
for i, column in enumerate(subfolder_details_df.columns[1:]):
    ax.bar(ind + i*width, subfolder_details_df[column], width, label=column, color=colors[i % len(colors)])

# Add x-axis labels
plt.xlabel('Name')
plt.ylabel('Count')
plt.title('Counts of Different Categories by Plant Name')
plt.xticks(ind, subfolder_details_df['name'])

# Add legend
plt.legend(loc='best')
plt.xticks(rotation=90)
# Show the plot
plt.show()

# %% [markdown]
# # ererere
