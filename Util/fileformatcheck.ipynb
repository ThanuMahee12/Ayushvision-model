# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanuMahee12/ayush-vision/blob/util/Util/fileformatcheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
for folder in list(map(lambda split:os.path.join('/content/drive/MyDrive/AYUSHVISION/working'),['train','val'])):
  for root,dirs,files in os.walk(folder):
    for file in files:
      name=os.path.splitext(file)
      print(name)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('leaves_indian Mallow_246', '.jpg')
# ('leaves_indian Mallow_248', '.jpg')
# ('leaves_indian Mallow_250', '.jpg')
# ('leaves_indian Mallow_253', '.jpg')
# ('leaves_indian Mallow_252', '.jpg')
# ('leaves_indian Mallow_251', '.jpg')
# ('leaves_indian Mallow_256', '.jpg')
# ('leaves_indian Mallow_255', '.jpg')
# ('leaves_indian Mallow_258', '.jpg')
# ('leaves_indian Mallow_257', '.jpg')
# ('leaves_indian Mallow_260', '.jpg')
# ('leaves_indian Mallow_259', '.jpg')
# ('leaves_indian Mallow_261', '.jpg')
# ('leaves_indian Mallow_264', '.jpg')
# ('leaves_indian Mallow_262', '.jpg')
# ('leaves_indian Mallow_266', '.jpg')
# ('leaves_indian Mallow_265', '.jpg')
# ('leaves_indian Mallow_267', '.jpg')
# ('leaves_indian Mallow_271', '.jpg')
# ('leaves_indian Mallow_276', '.jpg')
# ('leaves_indian Mallow_275', '.jpg')
# ('leaves_indian Mallow_277', '.jpg')
# ('leaves_indian Mallow_281', '.jpg')
# ('leaves_indian Mallow_283', '.jpg')
# ...
